# %% [markdown]
# ### Database Connection Via Python

# %% [markdown]
# #### Aim
#         Connecting Databse with 2 process
#         1. Using PyMySQL
#         2. Using SQLAlchemy

# %% [markdown]
# ##### 1. SQL Connection using PyMySQL

# %% [markdown]
# ##### Libraries

# %%
import pymysql  # for database connection
import pandas as pd # for dataframe

# %%
con=pymysql.connect(host='localhost',user='root',password='Ginni_25',port=3306,database='odin') # connection string 
cursor=con.cursor() # connction establish

# %%
strQry='select * from churn' # query for extracting result
cursor.execute(strQry) # query execution
# Out:
# 7043

# %%
df=pd.DataFrame(cursor.fetchall()) # storing data in dataframe

# %%
df.shape # shape of dataset
# Out:
# (7043, 33)

# %%
df.head(5) # first 5 rows of dataset
# Out:
#            0  1              2           3            4      5   \
# 0  3668-QPYBK  1  United States  California  Los Angeles  90003
# 1  9237-HQITU  1  United States  California  Los Angeles  90005
# 2  9305-CDSKC  1  United States  California  Los Angeles  90006
# 3  7892-POOKP  1  United States  California  Los Angeles  90010
# 4  0280-XJGEX  1  United States  California  Los Angeles  90015
#
#                        6          7            8       9   ...  \
# 0  33.964131; -118.272783  33.964131  -118.272783    Male  ...
# 1   34.059281; -118.30742  34.059281  -118.307420  Female  ...
# 2  34.048013; -118.293953  34.048013  -118.293953  Female  ...
# 3  34.062125; -118.315709  34.062125  -118.315709  Female  ...
# 4  34.039224; -118.266293  34.039224  -118.266293    Male  ...
#
#                23   24                         25     26       27   28 29  30  \
# 0  Month-to-month  Yes               Mailed check  53.85   108.15  Yes  1  86
# ...

# %% [markdown]
# ##### 1. SQL Connection using SQLAlchemy

# %% [markdown]
# ##### Libraries

# %%
from sqlalchemy import create_engine # for database connection
import pandas as pd # for datframe

# %%
db_con_str='mysql+mysqlconnector://root:Ginni_25@localhost:3306/odin' # connection string
db_con = create_engine(db_con_str)

# %%
df=pd.read_sql('select * from churn',con=db_con) 
#reading query from sql and storing data into dataframe

# %%
df.shape # shape of dataset
# Out:
# (7043, 33)

# %%
df.head(5) # first 5 rows of dataset
# Out:
#   Customer_ID Count        Country       State         City Zip_Code  \
# 0  3668-QPYBK     1  United States  California  Los Angeles    90003
# 1  9237-HQITU     1  United States  California  Los Angeles    90005
# 2  9305-CDSKC     1  United States  California  Los Angeles    90006
# 3  7892-POOKP     1  United States  California  Los Angeles    90010
# 4  0280-XJGEX     1  United States  California  Los Angeles    90015
#
#                  Lat_Long   Latitude    Longitude  Gender  ...  \
# 0  33.964131; -118.272783  33.964131  -118.272783    Male  ...
# 1   34.059281; -118.30742  34.059281  -118.307420  Female  ...
# 2  34.048013; -118.293953  34.048013  -118.293953  Female  ...
# 3  34.062125; -118.315709  34.062125  -118.315709  Female  ...
# 4  34.039224; -118.266293  34.039224  -118.266293    Male  ...
#
#          Contract Paperless_Billing             Payment_Method  \
# 0  Month-to-month               Yes               Mailed check
# ...
